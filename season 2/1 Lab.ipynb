# %% [markdown]
# ## 1 Задание

# %%
class Node:

    def __init__(self, data, next=None):
        self.data = data
        self.next = next

    def __str__(self): 
        if(self.next != None):
            return f"[Node with value {self.data}] \n{self.next}"
        else:
            return f"[Node with value {self.data}]"
        
class LinkedList:
    def __init__(self):
        self.head = None
    
    def __str__(self):
        return str(self.head)

# %%
def reverse_list(head, tail=None):
    while head:
        head.next, tail, head = tail, head, head.next
    return tail
        
        
        
linked_list = LinkedList()
temp = Node(1)
linked_list.head = temp
for i in range(2, 6):
    temp.next = Node(i)
    temp = temp.next

print(linked_list,"\n---")

h = reverse_list(linked_list.head)

print(h)
# Out:
# [Node with value 1]
# [Node with value 2]
# [Node with value 3]
# [Node with value 4]
# [Node with value 5]
# ---
# [Node with value 5]
# [Node with value 4]
# [Node with value 3]
# [Node with value 2]
# [Node with value 1]

# %% [markdown]
# ## 2 Задание

# %%
import random

def sortLinkedList(mainHead):
    head = mainHead
    while head:
        tempHead = head.next
        while tempHead:
            if (head.data>tempHead.data):
                head.data, tempHead.data = tempHead.data, head.data
            tempHead = tempHead.next
        head = head.next
    return mainHead

linked_list = LinkedList()
temp = Node(1)
linked_list.head = temp
for i in range(2, 11):
    temp.next = Node(i+random.randint(0,50))
    temp = temp.next

print(linked_list,"\n---")

print(sortLinkedList(linked_list.head))
# Out:
# [Node with value 1]
# [Node with value 51]
# [Node with value 10]
# [Node with value 24]
# [Node with value 36]
# [Node with value 16]
# [Node with value 14]
# [Node with value 9]
# [Node with value 43]
# [Node with value 35]
# ---
# [Node with value 1]
# [Node with value 9]
# [Node with value 10]
# [Node with value 14]
# [Node with value 16]
# [Node with value 24]
# [Node with value 35]
# [Node with value 36]
# [Node with value 43]
# [Node with value 51]

# %% [markdown]
# ## 3 Задание

# %% [markdown]
# ### 3,1

# %%
import pandas as pd
import seaborn as sns
tips = sns.load_dataset('tips')


df = tips[((tips['sex']=='Male')&
           (tips['smoker']=='Yes')&
           (tips['day']=='Fri')&
           (tips['time']=='Lunch'))]


print(df['total_bill'].mean())
# Out:
# 11.386666666666668

# %% [markdown]
# ### 3.2

# %%
import pandas as pd
import seaborn as sns
import numpy as np
iris = sns.load_dataset('iris')

df = iris.groupby('species').agg(np.ptp)

print(df)
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               1.5          2.1           0.9          0.5
# versicolor           2.1          1.4           2.1          0.8
# virginica            3.0          1.6           2.4          1.1

# %% [markdown]
# ### 3.3

# %%
import pandas as pd


df = pd.DataFrame({
     'country': ['Kazakhstan', 'Russia', 'Belarus', 'Ukraine'],
     'population': [17.04, 143.5, 9.5, 45.5],
     'square': [2724902, 17125191, 207600, 603628]
 })

df['Density'] = (df.population*1000000)/df.square 

print(df)
# Out:
#       country  population    square    Density
# 0  Kazakhstan       17.04   2724902   6.253436
# 1      Russia      143.50  17125191   8.379469
# 2     Belarus        9.50    207600  45.761079
# 3     Ukraine       45.50    603628  75.377550
